# %%
CATALOG = "marathos"
RAW_VOLUME_PATH = "/Volumes/marathos/default/raw"
RAW_CSV = "TWO_CENTURIES_OF_UM_RACES 2.csv"
RAW_FILE = f"{RAW_VOLUME_PATH}/{RAW_CSV}"

BRONZE_TABLE = f"{CATALOG}.bronze.races_raw"
SILVER_TABLE = f"{CATALOG}.silver.races_obt"
GOLD_SCHEMA = f"{CATALOG}.gold"

MIN_EVENT_YEAR = 2010
MIN_SPEED_KMH = 2.0
MAX_SPEED_KMH = 25.0
